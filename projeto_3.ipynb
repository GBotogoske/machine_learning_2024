# %%
import ROOT
import matplotlib.pyplot as plt
import numpy as np
import keras

# %%
#vamos abrir os arquivos root
nome1="vhcc_tree.root"
nome2="dyll-nlo_tree.root"
file1= ROOT.TFile.Open( nome1 , "READ" )
file2= ROOT.TFile.Open( nome2 , "READ" )

# %%
#vamos pegar a TTree
tree1 = file1.Get("Events")
tree2 = file2.Get("Events")

# %%
#coletando os dados
from data_classes import Data

data_1=Data()
data_2=Data()

n_max_1=tree1.GetEntries()

for entryNum in range (0 ,n_max_1):
    tree1.GetEntry( entryNum )
    data_1.ak15_regressed_mass.append(getattr(tree1, "ak15_regressed_mass"))
    data_1.lep1_pt.append(getattr(tree1, "lep1_pt"))
    data_1.lep1_eta.append(getattr(tree1, "lep1_eta"))
    data_1.lep1_phi.append(getattr(tree1, "lep1_phi"))
    data_1.lep1_mass.append(getattr(tree1, "lep1_mass"))
    data_1.lep2_pt.append(getattr(tree1, "lep2_pt"))
    data_1.lep2_eta.append(getattr(tree1, "lep2_eta"))
    data_1.lep2_phi.append(getattr(tree1, "lep2_phi"))
    data_1.lep2_mass.append(getattr(tree1, "lep2_mass"))
    data_1.ak15_pt.append(getattr(tree1, "ak15_pt"))
    data_1.ak15_eta.append(getattr(tree1, "ak15_eta"))
    data_1.ak15_phi.append(getattr(tree1, "ak15_phi"))
    data_1.ak15_deltaR_sj12.append(getattr(tree1, "ak15_deltaR_sj12"))
    data_1.ak15_sj1_pt.append(getattr(tree1, "ak15_sj1_pt"))
    data_1.ak15_sj2_pt.append(getattr(tree1, "ak15_sj2_pt"))      

n_max_2=tree2.GetEntries()

for entryNum in range (0 ,n_max_2):
    tree2.GetEntry( entryNum )
    data_2.ak15_regressed_mass.append(getattr(tree2, "ak15_regressed_mass"))
    data_2.lep1_pt.append(getattr(tree1, "lep1_pt"))
    data_2.lep1_eta.append(getattr(tree1, "lep1_eta"))
    data_2.lep1_phi.append(getattr(tree1, "lep1_phi"))
    data_2.lep1_mass.append(getattr(tree1, "lep1_mass"))
    data_2.lep2_pt.append(getattr(tree1, "lep2_pt"))
    data_2.lep2_eta.append(getattr(tree1, "lep2_eta"))
    data_2.lep2_phi.append(getattr(tree1, "lep2_phi"))
    data_2.lep2_mass.append(getattr(tree1, "lep2_mass"))
    data_2.ak15_pt.append(getattr(tree1, "ak15_pt"))
    data_2.ak15_eta.append(getattr(tree1, "ak15_eta"))
    data_2.ak15_phi.append(getattr(tree1, "ak15_phi"))
    data_2.ak15_deltaR_sj12.append(getattr(tree1, "ak15_deltaR_sj12"))
    data_2.ak15_sj1_pt.append(getattr(tree1, "ak15_sj1_pt"))
    data_2.ak15_sj2_pt.append(getattr(tree1, "ak15_sj2_pt"))

# %%
#plotando histograma de massa?

plt.hist( data_1.ak15_regressed_mass,bins=100,fill=False, histtype='step', label="higgs data")
plt.hist( data_2.ak15_regressed_mass[:n_max_1],bins=100, fill=False, histtype='step', label="background data")
plt.legend()

plt.draw()

# %%
#arranjando os dados de forma aleatoria

data=Data()

random1=np.random.choice(n_max_1,n_max_1,replace=False) #inteiros ate o primeiro numero. Numero de eventos sorteados igual ao segundo numero
random2=np.random.choice(n_max_2,n_max_1,replace=False)
random_position=np.random.choice(2*n_max_1,n_max_1,replace=False)

is_here=np.zeros(n_max_1*2)
is_here[random_position] = 1


cont1=0
cont2=0

for cont in range(n_max_1*2):
    if is_here[cont]==1:

        data.ak15_regressed_mass.append(data_1.ak15_regressed_mass[random1[cont1]])
        data.lep1_pt.append(data_1.lep1_pt[random1[cont1]])
        data.lep1_eta.append(data_1.lep1_eta[random1[cont1]])
        data.lep1_phi.append(data_1.lep1_phi[random1[cont1]])
        data.lep1_mass.append(data_1.lep1_mass[random1[cont1]])
        data.lep2_pt.append(data_1.lep2_pt[random1[cont1]])
        data.lep2_eta.append(data_1.lep2_eta[random1[cont1]])
        data.lep2_phi.append(data_1.lep2_phi[random1[cont1]])
        data.lep2_mass.append(data_1.lep2_mass[random1[cont1]])
        data.ak15_pt.append(data_1.ak15_pt[random1[cont1]])
        data.ak15_eta.append(data_1.ak15_eta[random1[cont1]])
        data.ak15_phi.append(data_1.ak15_phi[random1[cont1]])
        data.ak15_deltaR_sj12.append(data_1.ak15_deltaR_sj12[random1[cont1]])
        data.ak15_sj1_pt.append(data_1.ak15_sj1_pt[random1[cont1]])
        data.ak15_sj2_pt.append(data_1.ak15_sj2_pt[random1[cont1]])

        data.truth.append(1)
        cont1=cont1+1

    if is_here[cont]==0:
        data.ak15_regressed_mass.append(data_2.ak15_regressed_mass[random2[cont2]])
        data.lep1_pt.append(data_2.lep1_pt[random2[cont2]])
        data.lep1_eta.append(data_2.lep1_eta[random2[cont2]])
        data.lep1_phi.append(data_2.lep1_phi[random2[cont2]])
        data.lep1_mass.append(data_2.lep1_mass[random2[cont2]])
        data.lep2_pt.append(data_2.lep2_pt[random2[cont2]])
        data.lep2_eta.append(data_2.lep2_eta[random2[cont2]])
        data.lep2_phi.append(data_2.lep2_phi[random2[cont2]])
        data.lep2_mass.append(data_2.lep2_mass[random2[cont2]])
        data.ak15_pt.append(data_2.ak15_pt[random2[cont2]])
        data.ak15_eta.append(data_2.ak15_eta[random2[cont2]])
        data.ak15_phi.append(data_2.ak15_phi[random2[cont2]])
        data.ak15_deltaR_sj12.append(data_2.ak15_deltaR_sj12[random2[cont2]])
        data.ak15_sj1_pt.append(data_2.ak15_sj1_pt[random2[cont2]])
        data.ak15_sj2_pt.append(data_2.ak15_sj2_pt[random2[cont2]])

        data.truth.append(0)
        cont2=cont2+1

# %%
#modelo da rede neural sendo montado
#vamos tentar no comeco apesar usar os dados de lep

from keras import models,layers,initializers

model= models.Sequential(name="my_neural")
model.add(layers.Input(shape=(6,)))
model.add(layers.Dense(8,activation="relu"))
model.add(layers.Dense(8,activation="relu"))
model.add(layers.Dense(1,activation="sigmoid"))

model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
def make_correction_format(data_in):
    return np.array(data_in).reshape(1,-1)

# %%
#tenho que montar eu mesmo
n_max=len(data.truth)
input_data = [[] for _ in range(6)]

input_data[0]=np.array(data.lep1_pt)
input_data[1]=np.array(data.lep1_eta)
input_data[2]=np.array(data.lep1_phi)
input_data[3]=np.array(data.lep2_pt)
input_data[4]=np.array(data.lep2_eta)
input_data[5]=np.array(data.lep2_phi)

input_data=np.array(input_data).transpose()

input_data=np.stack(input_data,axis=0)

# %%
#separando os dados
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(input_data,data.truth,random_state=42)

# %%
x_train=np.array(x_train)
y_train=np.array(y_train)
x_test=np.array(x_test)
y_test=np.array(y_test)

# %%
model.summary()
# Out:
# Model: "my_neural"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 8)              │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 137 (548.00 B)
#  Trainable params: 137 (548.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#treino
history = model.fit(x_train,y_train,epochs=100,batch_size=15000,validation_data=(x_test,y_test))
# Out:
# Epoch 1/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4989 - loss: 26.4659 - val_accuracy: 0.5017 - val_loss: 13.3167
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4669 - loss: 9.3186 - val_accuracy: 0.2741 - val_loss: 2.9748
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2434 - loss: 2.1822 - val_accuracy: 0.3741 - val_loss: 0.7354
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6702 - loss: 0.6141 - val_accuracy: 0.9130 - val_loss: 0.4520
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9115 - loss: 0.4372 - val_accuracy: 0.9025 - val_loss: 0.4059
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9005 - loss: 0.3973 - val_accuracy: 0.9030 - val_loss: 0.3738
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9048 - loss: 0.3648 - val_accuracy: 0.9199 - val_loss: 0.3331
# Epoch 8/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9248 - loss: 0.3187 - val_accuracy: 0.9460 - val_loss: 0.2689
# Epoch 9/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9520 - loss: 0.2628 - val_accuracy: 0.9571 - val_loss: 0.2475
# Epoch 10/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9549 - loss: 0.2436 - val_accuracy: 0.9556 - val_loss: 0.2325
# Epoch 11/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9552 - loss: 0.2291 - val_accuracy: 0.9550 - val_loss: 0.2201
# Epoch 12/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9566 - loss: 0.2168 - val_accuracy: 0.9586 - val_loss: 0.2086
# Epoch 13/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9587 - loss: 0.2063 - val_accuracy: 0.9606 - val_loss: 0.1980
# Epoch 14/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9610 - loss: 0.1954 - val_accuracy: 0.9628 - val_loss: 0.1884
# Epoch 15/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9627 - loss: 0.1853 - val_accuracy: 0.9633 - val_loss: 0.1794
# Epoch 16/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9638 - loss: 0.1770 - val_accuracy: 0.9656 - val_loss: 0.1708
# Epoch 17/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9656 - loss: 0.1683 - val_accuracy: 0.9666 - val_loss: 0.1626
# Epoch 18/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9669 - loss: 0.1606 - val_accuracy: 0.9681 - val_loss: 0.1557
# Epoch 19/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9683 - loss: 0.1535 - val_accuracy: 0.9689 - val_loss: 0.1475
# Epoch 20/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9697 - loss: 0.1459 - val_accuracy: 0.9711 - val_loss: 0.1415
# Epoch 21/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9711 - loss: 0.1391 - val_accuracy: 0.9714 - val_loss: 0.1345
# Epoch 22/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9719 - loss: 0.1333 - val_accuracy: 0.9725 - val_loss: 0.1286
# Epoch 23/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9731 - loss: 0.1273 - val_accuracy: 0.9744 - val_loss: 0.1227
# Epoch 24/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9743 - loss: 0.1214 - val_accuracy: 0.9751 - val_loss: 0.1171
# Epoch 25/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9751 - loss: 0.1159 - val_accuracy: 0.9758 - val_loss: 0.1126
# Epoch 26/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9755 - loss: 0.1120 - val_accuracy: 0.9771 - val_loss: 0.1073
# Epoch 27/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9769 - loss: 0.1065 - val_accuracy: 0.9774 - val_loss: 0.1031
# Epoch 28/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9775 - loss: 0.1023 - val_accuracy: 0.9783 - val_loss: 0.0987
# Epoch 29/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0977 - val_accuracy: 0.9794 - val_loss: 0.0947
# Epoch 30/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9794 - loss: 0.0943 - val_accuracy: 0.9798 - val_loss: 0.0912
# Epoch 31/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9799 - loss: 0.0905 - val_accuracy: 0.9802 - val_loss: 0.0877
# Epoch 32/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9807 - loss: 0.0865 - val_accuracy: 0.9815 - val_loss: 0.0842
# Epoch 33/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9811 - loss: 0.0838 - val_accuracy: 0.9815 - val_loss: 0.0811
# Epoch 34/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9816 - loss: 0.0805 - val_accuracy: 0.9823 - val_loss: 0.0780
# Epoch 35/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9823 - loss: 0.0776 - val_accuracy: 0.9828 - val_loss: 0.0754
# Epoch 36/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9827 - loss: 0.0752 - val_accuracy: 0.9825 - val_loss: 0.0733
# Epoch 37/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9833 - loss: 0.0724 - val_accuracy: 0.9835 - val_loss: 0.0702
# Epoch 38/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9836 - loss: 0.0699 - val_accuracy: 0.9839 - val_loss: 0.0681
# Epoch 39/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9840 - loss: 0.0675 - val_accuracy: 0.9849 - val_loss: 0.0655
# Epoch 40/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9847 - loss: 0.0652 - val_accuracy: 0.9850 - val_loss: 0.0634
# Epoch 41/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9849 - loss: 0.0631 - val_accuracy: 0.9855 - val_loss: 0.0613
# Epoch 42/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9854 - loss: 0.0612 - val_accuracy: 0.9861 - val_loss: 0.0594
# Epoch 43/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9859 - loss: 0.0594 - val_accuracy: 0.9864 - val_loss: 0.0576
# Epoch 44/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9863 - loss: 0.0573 - val_accuracy: 0.9868 - val_loss: 0.0560
# Epoch 45/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9865 - loss: 0.0556 - val_accuracy: 0.9871 - val_loss: 0.0542
# Epoch 46/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9869 - loss: 0.0543 - val_accuracy: 0.9874 - val_loss: 0.0526
# Epoch 47/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9873 - loss: 0.0524 - val_accuracy: 0.9876 - val_loss: 0.0511
# Epoch 48/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9873 - loss: 0.0512 - val_accuracy: 0.9883 - val_loss: 0.0498
# Epoch 49/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9878 - loss: 0.0494 - val_accuracy: 0.9884 - val_loss: 0.0484
# Epoch 50/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9877 - loss: 0.0485 - val_accuracy: 0.9886 - val_loss: 0.0470
# Epoch 51/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9883 - loss: 0.0465 - val_accuracy: 0.9892 - val_loss: 0.0457
# Epoch 52/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9884 - loss: 0.0462 - val_accuracy: 0.9889 - val_loss: 0.0447
# Epoch 53/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9890 - loss: 0.0443 - val_accuracy: 0.9895 - val_loss: 0.0434
# Epoch 54/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9890 - loss: 0.0434 - val_accuracy: 0.9896 - val_loss: 0.0423
# Epoch 55/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9894 - loss: 0.0421 - val_accuracy: 0.9899 - val_loss: 0.0412
# Epoch 56/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9894 - loss: 0.0418 - val_accuracy: 0.9900 - val_loss: 0.0403
# Epoch 57/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9896 - loss: 0.0405 - val_accuracy: 0.9902 - val_loss: 0.0392
# Epoch 58/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9901 - loss: 0.0390 - val_accuracy: 0.9910 - val_loss: 0.0384
# Epoch 59/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9902 - loss: 0.0385 - val_accuracy: 0.9908 - val_loss: 0.0374
# Epoch 60/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9903 - loss: 0.0371 - val_accuracy: 0.9912 - val_loss: 0.0365
# Epoch 61/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9909 - loss: 0.0363 - val_accuracy: 0.9910 - val_loss: 0.0356
# Epoch 62/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9909 - loss: 0.0354 - val_accuracy: 0.9913 - val_loss: 0.0348
# Epoch 63/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9908 - loss: 0.0351 - val_accuracy: 0.9915 - val_loss: 0.0340
# Epoch 64/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9911 - loss: 0.0341 - val_accuracy: 0.9917 - val_loss: 0.0333
# Epoch 65/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9912 - loss: 0.0334 - val_accuracy: 0.9917 - val_loss: 0.0327
# Epoch 66/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9914 - loss: 0.0327 - val_accuracy: 0.9921 - val_loss: 0.0318
# Epoch 67/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9916 - loss: 0.0320 - val_accuracy: 0.9919 - val_loss: 0.0312
# Epoch 68/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9915 - loss: 0.0316 - val_accuracy: 0.9921 - val_loss: 0.0305
# Epoch 69/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9919 - loss: 0.0305 - val_accuracy: 0.9922 - val_loss: 0.0301
# Epoch 70/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9921 - loss: 0.0297 - val_accuracy: 0.9926 - val_loss: 0.0294
# Epoch 71/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9922 - loss: 0.0293 - val_accuracy: 0.9923 - val_loss: 0.0287
# Epoch 72/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9924 - loss: 0.0286 - val_accuracy: 0.9928 - val_loss: 0.0282
# Epoch 73/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9925 - loss: 0.0279 - val_accuracy: 0.9931 - val_loss: 0.0276
# Epoch 74/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9928 - loss: 0.0273 - val_accuracy: 0.9933 - val_loss: 0.0270
# Epoch 75/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9927 - loss: 0.0272 - val_accuracy: 0.9932 - val_loss: 0.0266
# Epoch 76/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9928 - loss: 0.0267 - val_accuracy: 0.9934 - val_loss: 0.0259
# Epoch 77/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9932 - loss: 0.0255 - val_accuracy: 0.9935 - val_loss: 0.0255
# Epoch 78/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9935 - loss: 0.0249 - val_accuracy: 0.9937 - val_loss: 0.0250
# Epoch 79/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9932 - loss: 0.0250 - val_accuracy: 0.9935 - val_loss: 0.0245
# Epoch 80/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9933 - loss: 0.0244 - val_accuracy: 0.9938 - val_loss: 0.0241
# Epoch 81/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9935 - loss: 0.0237 - val_accuracy: 0.9941 - val_loss: 0.0236
# Epoch 82/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9939 - loss: 0.0231 - val_accuracy: 0.9941 - val_loss: 0.0232
# Epoch 83/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9939 - loss: 0.0228 - val_accuracy: 0.9943 - val_loss: 0.0228
# Epoch 84/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9941 - loss: 0.0222 - val_accuracy: 0.9943 - val_loss: 0.0223
# Epoch 85/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9940 - loss: 0.0222 - val_accuracy: 0.9946 - val_loss: 0.0220
# Epoch 86/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9943 - loss: 0.0214 - val_accuracy: 0.9947 - val_loss: 0.0216
# Epoch 87/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9943 - loss: 0.0215 - val_accuracy: 0.9945 - val_loss: 0.0212
# Epoch 88/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9943 - loss: 0.0211 - val_accuracy: 0.9948 - val_loss: 0.0208
# Epoch 89/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9944 - loss: 0.0210 - val_accuracy: 0.9945 - val_loss: 0.0205
# Epoch 90/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9945 - loss: 0.0205 - val_accuracy: 0.9948 - val_loss: 0.0201
# Epoch 91/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9946 - loss: 0.0198 - val_accuracy: 0.9951 - val_loss: 0.0197
# Epoch 92/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9948 - loss: 0.0194 - val_accuracy: 0.9950 - val_loss: 0.0194
# Epoch 93/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9948 - loss: 0.0192 - val_accuracy: 0.9952 - val_loss: 0.0191
# Epoch 94/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0188 - val_accuracy: 0.9953 - val_loss: 0.0188
# Epoch 95/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9950 - loss: 0.0185 - val_accuracy: 0.9953 - val_loss: 0.0185
# Epoch 96/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9953 - loss: 0.0179 - val_accuracy: 0.9954 - val_loss: 0.0182
# Epoch 97/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9952 - loss: 0.0180 - val_accuracy: 0.9954 - val_loss: 0.0179
# Epoch 98/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9953 - loss: 0.0177 - val_accuracy: 0.9956 - val_loss: 0.0177
# Epoch 99/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9953 - loss: 0.0174 - val_accuracy: 0.9954 - val_loss: 0.0174
# Epoch 100/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9955 - loss: 0.0168 - val_accuracy: 0.9956 - val_loss: 0.0170

# %%
# Accessing the training loss history
training_loss = history.history['loss']

# Accessing the validation loss history
validation_loss = history.history['val_loss']

# %%
# Plot training & validation loss values
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#plotando histograma da previsao e do valor real
y_pred_prob = model.predict(x_test) 
plt.hist(y_test, bins=100, fill=False, histtype='step', label="real data")
plt.hist(y_pred_prob,bins=100, fill=False, histtype='step', label="predicted data")
plt.legend()

plt.show()
# Out:
# 5192/5192 ━━━━━━━━━━━━━━━━━━━━ 2s 461us/step

# %%
from sklearn.metrics import roc_curve, auc

# Compute ROC curve and ROC area
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

#best threshold
J = tpr - fpr
best_threshold_index = np.argmax(J)
best_threshold = thresholds[best_threshold_index]

# Annotate some thresholds on the ROC curve
for i in range(0, len(thresholds), len(thresholds) // 10):
    plt.annotate(f'{thresholds[i]:.2f}', (fpr[i], tpr[i]), textcoords="offset points", xytext=(0,10), ha='center')

# Highlight the best threshold point
plt.scatter(fpr[best_threshold_index], tpr[best_threshold_index], color='red', label=f'Best Threshold = {best_threshold:.2f}')
plt.annotate(f'Threshold = {best_threshold:.2f}', 
             (fpr[best_threshold_index], tpr[best_threshold_index]), 
             textcoords="offset points", 
             xytext=(0,10), 
             ha='center', 
             color='red')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %%
#creating data with true rate: 1:10000

#arranjando os dados de forma aleatoria

data_with_rate=Data()

total=n_max_1*2
rate1=int(total*0.001)
rate2=total-rate1

random1=np.random.choice(n_max_1,rate1,replace=False) #inteiros ate o primeiro numero. Numero de eventos sorteados igual ao segundo numero
random2=np.random.choice(n_max_2,rate2,replace=False)

random_position=np.random.choice(2*n_max_1,rate1,replace=False)

is_here=np.zeros(n_max_1*2)
is_here[random_position] = 1

cont1=0
cont2=0

for cont in range(n_max_1*2):
    if is_here[cont]==1:
        data_with_rate.ak15_regressed_mass.append(data_1.ak15_regressed_mass[random1[cont1]])
        data_with_rate.lep1_pt.append(data_1.lep1_pt[random1[cont1]])
        data_with_rate.lep1_eta.append(data_1.lep1_eta[random1[cont1]])
        data_with_rate.lep1_phi.append(data_1.lep1_phi[random1[cont1]])
        data_with_rate.lep1_mass.append(data_1.lep1_mass[random1[cont1]])
        data_with_rate.lep2_pt.append(data_1.lep2_pt[random1[cont1]])
        data_with_rate.lep2_eta.append(data_1.lep2_eta[random1[cont1]])
        data_with_rate.lep2_phi.append(data_1.lep2_phi[random1[cont1]])
        data_with_rate.lep2_mass.append(data_1.lep2_mass[random1[cont1]])
        data_with_rate.ak15_pt.append(data_1.ak15_pt[random1[cont1]])
        data_with_rate.ak15_eta.append(data_1.ak15_eta[random1[cont1]])
        data_with_rate.ak15_phi.append(data_1.ak15_phi[random1[cont1]])
        data_with_rate.ak15_deltaR_sj12.append(data_1.ak15_deltaR_sj12[random1[cont1]])
        data_with_rate.ak15_sj1_pt.append(data_1.ak15_sj1_pt[random1[cont1]])
        data_with_rate.ak15_sj2_pt.append(data_1.ak15_sj2_pt[random1[cont1]])

        data_with_rate.truth.append(1)
        cont1=cont1+1



    if is_here[cont]==0:
        data_with_rate.ak15_regressed_mass.append(data_2.ak15_regressed_mass[random2[cont2]])
        data_with_rate.lep1_pt.append(data_2.lep1_pt[random2[cont2]])
        data_with_rate.lep1_eta.append(data_2.lep1_eta[random2[cont2]])
        data_with_rate.lep1_phi.append(data_2.lep1_phi[random2[cont2]])
        data_with_rate.lep1_mass.append(data_2.lep1_mass[random2[cont2]])
        data_with_rate.lep2_pt.append(data_2.lep2_pt[random2[cont2]])
        data_with_rate.lep2_eta.append(data_2.lep2_eta[random2[cont2]])
        data_with_rate.lep2_phi.append(data_2.lep2_phi[random2[cont2]])
        data_with_rate.lep2_mass.append(data_2.lep2_mass[random2[cont2]])
        data_with_rate.ak15_pt.append(data_2.ak15_pt[random2[cont2]])
        data_with_rate.ak15_eta.append(data_2.ak15_eta[random2[cont2]])
        data_with_rate.ak15_phi.append(data_2.ak15_phi[random2[cont2]])
        data_with_rate.ak15_deltaR_sj12.append(data_2.ak15_deltaR_sj12[random2[cont2]])
        data_with_rate.ak15_sj1_pt.append(data_2.ak15_sj1_pt[random2[cont2]])
        data_with_rate.ak15_sj2_pt.append(data_2.ak15_sj2_pt[random2[cont2]])

        data_with_rate.truth.append(0)
        cont2=cont2+1

# %%
#tenho que montar eu mesmo
n_max=len(data.truth)
input_data = [[] for _ in range(6)]

input_data[0]=np.array(data_with_rate.lep1_pt)
input_data[1]=np.array(data_with_rate.lep1_eta)
input_data[2]=np.array(data_with_rate.lep1_phi)
input_data[3]=np.array(data_with_rate.lep2_pt)
input_data[4]=np.array(data_with_rate.lep2_eta)
input_data[5]=np.array(data_with_rate.lep2_phi)

input_data=np.array(input_data).transpose()

input_data=np.stack(input_data,axis=0)

# %%
#plotando histograma da previsao e do valor real
y_pred_prob = model.predict(input_data) 
plt.hist(data_with_rate.truth, bins=100, fill=False, histtype='step', label="real data")
plt.hist(y_pred_prob,bins=100, fill=False, histtype='step', label="predicted data")
plt.legend()

plt.show()
# Out:
# 20766/20766 ━━━━━━━━━━━━━━━━━━━━ 11s 530us/step

# %%
# Compute ROC curve and ROC area
fpr, tpr, thresholds = roc_curve(data_with_rate.truth, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

#best threshold
J = tpr - fpr
best_threshold_index = np.argmax(J)
best_threshold = thresholds[best_threshold_index]

# Annotate some thresholds on the ROC curve
for i in range(0, len(thresholds), len(thresholds) // 10):
    plt.annotate(f'{thresholds[i]:.2f}', (fpr[i], tpr[i]), textcoords="offset points", xytext=(0,10), ha='center')

# Highlight the best threshold point
plt.scatter(fpr[best_threshold_index], tpr[best_threshold_index], color='red', label=f'Best Threshold = {best_threshold:.2f}')
plt.annotate(f'Threshold = {best_threshold:.2f}', 
             (fpr[best_threshold_index], tpr[best_threshold_index]), 
             textcoords="offset points", 
             xytext=(0,10), 
             ha='center', 
             color='red')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %%
tpr[best_threshold_index]
# Out:
# 0.9984939759036144
