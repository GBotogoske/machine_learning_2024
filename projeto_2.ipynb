# %%
import ROOT
import matplotlib.pyplot as plt
import numpy as np
import keras
# Out:
# 2024-09-24 07:25:10.275002: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-24 07:25:10.275593: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-24 07:25:10.283278: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-24 07:25:10.357202: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-24 07:25:11.808384: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#vamos abrir os arquivos root
nome1="vhcc_tree.root"
nome2="dyll-nlo_tree.root"
file1= ROOT.TFile.Open( nome1 , "READ" )
file2= ROOT.TFile.Open( nome2 , "READ" )

# %%
#vamos pegar a TTree
tree1 = file1.Get("Events")
tree2 = file2.Get("Events")

# %%
#coletando os dados
from data_classes import Data

data_1=Data()
data_2=Data()

n_max_1=tree1.GetEntries()

for entryNum in range (0 ,n_max_1):
    tree1.GetEntry( entryNum )
    data_1.ak15_regressed_mass.append(getattr(tree1, "ak15_regressed_mass"))
    data_1.lep1_pt.append(getattr(tree1, "lep1_pt"))
    data_1.lep1_eta.append(getattr(tree1, "lep1_eta"))
    data_1.lep1_phi.append(getattr(tree1, "lep1_phi"))
    data_1.lep1_mass.append(getattr(tree1, "lep1_mass"))
    data_1.lep2_pt.append(getattr(tree1, "lep2_pt"))
    data_1.lep2_eta.append(getattr(tree1, "lep2_eta"))
    data_1.lep2_phi.append(getattr(tree1, "lep2_phi"))
    data_1.lep2_mass.append(getattr(tree1, "lep2_mass"))
    data_1.ak15_pt.append(getattr(tree1, "ak15_pt"))
    data_1.ak15_eta.append(getattr(tree1, "ak15_eta"))
    data_1.ak15_phi.append(getattr(tree1, "ak15_phi"))
    data_1.ak15_deltaR_sj12.append(getattr(tree1, "ak15_deltaR_sj12"))
    data_1.ak15_sj1_pt.append(getattr(tree1, "ak15_sj1_pt"))
    data_1.ak15_sj2_pt.append(getattr(tree1, "ak15_sj2_pt"))      

n_max_2=tree2.GetEntries()

for entryNum in range (0 ,n_max_2):
    tree2.GetEntry( entryNum )
    data_2.ak15_regressed_mass.append(getattr(tree2, "ak15_regressed_mass"))
    data_2.lep1_pt.append(getattr(tree1, "lep1_pt"))
    data_2.lep1_eta.append(getattr(tree1, "lep1_eta"))
    data_2.lep1_phi.append(getattr(tree1, "lep1_phi"))
    data_2.lep1_mass.append(getattr(tree1, "lep1_mass"))
    data_2.lep2_pt.append(getattr(tree1, "lep2_pt"))
    data_2.lep2_eta.append(getattr(tree1, "lep2_eta"))
    data_2.lep2_phi.append(getattr(tree1, "lep2_phi"))
    data_2.lep2_mass.append(getattr(tree1, "lep2_mass"))
    data_2.ak15_pt.append(getattr(tree1, "ak15_pt"))
    data_2.ak15_eta.append(getattr(tree1, "ak15_eta"))
    data_2.ak15_phi.append(getattr(tree1, "ak15_phi"))
    data_2.ak15_deltaR_sj12.append(getattr(tree1, "ak15_deltaR_sj12"))
    data_2.ak15_sj1_pt.append(getattr(tree1, "ak15_sj1_pt"))
    data_2.ak15_sj2_pt.append(getattr(tree1, "ak15_sj2_pt"))

# %%
#plotando histograma de massa?

plt.hist( data_1.ak15_regressed_mass,bins=100,fill=False, histtype='step', label="higgs data")
plt.hist( data_2.ak15_regressed_mass[:n_max_1],bins=100, fill=False, histtype='step', label="background data")
plt.legend()

plt.draw()

# %%
#arranjando os dados de forma aleatoria

data=Data()

random1=np.random.choice(n_max_1,n_max_1,replace=False) #inteiros ate o primeiro numero. Numero de eventos sorteados igual ao segundo numero
random2=np.random.choice(n_max_2,n_max_1,replace=False)
random_position=np.random.choice(2*n_max_1,n_max_1,replace=False)

is_here=np.zeros(n_max_1*2)
is_here[random_position] = 1


cont1=0
cont2=0

for cont in range(n_max_1*2):
    if is_here[cont]==0:

        data.ak15_regressed_mass.append(data_1.ak15_regressed_mass[random1[cont1]])
        data.lep1_pt.append(data_1.lep1_pt[random1[cont1]])
        data.lep1_eta.append(data_1.lep1_eta[random1[cont1]])
        data.lep1_phi.append(data_1.lep1_phi[random1[cont1]])
        data.lep1_mass.append(data_1.lep1_mass[random1[cont1]])
        data.lep2_pt.append(data_1.lep2_pt[random1[cont1]])
        data.lep2_eta.append(data_1.lep2_eta[random1[cont1]])
        data.lep2_phi.append(data_1.lep2_phi[random1[cont1]])
        data.lep2_mass.append(data_1.lep2_mass[random1[cont1]])
        data.ak15_pt.append(data_1.ak15_pt[random1[cont1]])
        data.ak15_eta.append(data_1.ak15_eta[random1[cont1]])
        data.ak15_phi.append(data_1.ak15_phi[random1[cont1]])
        data.ak15_deltaR_sj12.append(data_1.ak15_deltaR_sj12[random1[cont1]])
        data.ak15_sj1_pt.append(data_1.ak15_sj1_pt[random1[cont1]])
        data.ak15_sj2_pt.append(data_1.ak15_sj2_pt[random1[cont1]])

        data.truth.append(1)
        cont1=cont1+1

    if is_here[cont]==0:
        data.ak15_regressed_mass.append(data_2.ak15_regressed_mass[random2[cont2]])
        data.lep1_pt.append(data_2.lep1_pt[random2[cont2]])
        data.lep1_eta.append(data_2.lep1_eta[random2[cont2]])
        data.lep1_phi.append(data_2.lep1_phi[random2[cont2]])
        data.lep1_mass.append(data_2.lep1_mass[random2[cont2]])
        data.lep2_pt.append(data_2.lep2_pt[random2[cont2]])
        data.lep2_eta.append(data_2.lep2_eta[random2[cont2]])
        data.lep2_phi.append(data_2.lep2_phi[random2[cont2]])
        data.lep2_mass.append(data_2.lep2_mass[random2[cont2]])
        data.ak15_pt.append(data_2.ak15_pt[random2[cont2]])
        data.ak15_eta.append(data_2.ak15_eta[random2[cont2]])
        data.ak15_phi.append(data_2.ak15_phi[random2[cont2]])
        data.ak15_deltaR_sj12.append(data_2.ak15_deltaR_sj12[random2[cont2]])
        data.ak15_sj1_pt.append(data_2.ak15_sj1_pt[random2[cont2]])
        data.ak15_sj2_pt.append(data_2.ak15_sj2_pt[random2[cont2]])

        data.truth.append(0)
        cont2=cont2+1

# %%
#modelo da rede neural sendo montado
#vamos tentar no comeco apesar usar os dados de ak?

from keras import models,layers,initializers

model= models.Sequential(name="my_neural")
model.add(layers.Input(shape=(6,)))
model.add(layers.Dense(8,activation="relu"))
model.add(layers.Dense(8,activation="relu"))
model.add(layers.Dense(1,activation="sigmoid"))

model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
def make_correction_format(data_in):
    return np.array(data_in).reshape(1,-1)

# %%
#tenho que montar eu mesmo
n_max=len(data.truth)
input_data = [[] for _ in range(6)]

input_data[0]=np.array(data.ak15_pt)
input_data[1]=np.array(data.ak15_eta)
input_data[2]=np.array(data.ak15_phi)
input_data[3]=np.array(data.ak15_deltaR_sj12)
input_data[4]=np.array(data.ak15_sj1_pt)
input_data[5]=np.array(data.ak15_sj2_pt)

input_data=np.array(input_data).transpose()

input_data=np.stack(input_data,axis=0)

# %%
#separando os dados
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(input_data,data.truth,random_state=42)

# %%
x_train=np.array(x_train)
y_train=np.array(y_train)
x_test=np.array(x_test)
y_test=np.array(y_test)

# %%
model.summary()
# Out:
# Model: "my_neural"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 137 (548.00 B)
#  Trainable params: 137 (548.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#treino
history = model.fit(x_train,y_train,epochs=100,batch_size=15000,validation_data=(x_test,y_test))
# Out:
# Epoch 1/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5004 - loss: 37.9112 - val_accuracy: 0.4989 - val_loss: 21.1626
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4930 - loss: 15.8295 - val_accuracy: 0.2514 - val_loss: 2.9011
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4869 - loss: 2.9284 - val_accuracy: 0.2588 - val_loss: 2.2923
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2580 - loss: 2.1604 - val_accuracy: 0.2740 - val_loss: 1.7238
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2858 - loss: 1.5795 - val_accuracy: 0.3090 - val_loss: 1.1803
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4684 - loss: 1.0565 - val_accuracy: 0.8461 - val_loss: 0.7338
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8581 - loss: 0.6464 - val_accuracy: 0.8891 - val_loss: 0.4425
# Epoch 8/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9023 - loss: 0.3976 - val_accuracy: 0.9268 - val_loss: 0.2960
# Epoch 9/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9345 - loss: 0.2742 - val_accuracy: 0.9475 - val_loss: 0.2237
# Epoch 10/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9516 - loss: 0.2107 - val_accuracy: 0.9661 - val_loss: 0.1812
# Epoch 11/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9627 - loss: 0.1738 - val_accuracy: 0.9677 - val_loss: 0.1575
# Epoch 12/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9678 - loss: 0.1536 - val_accuracy: 0.9718 - val_loss: 0.1441
# Epoch 13/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9706 - loss: 0.1409 - val_accuracy: 0.9701 - val_loss: 0.1336
# Epoch 14/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9722 - loss: 0.1303 - val_accuracy: 0.9748 - val_loss: 0.1260
# Epoch 15/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9744 - loss: 0.1242 - val_accuracy: 0.9764 - val_loss: 0.1205
# Epoch 16/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9758 - loss: 0.1181 - val_accuracy: 0.9757 - val_loss: 0.1156
# Epoch 17/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9761 - loss: 0.1136 - val_accuracy: 0.9770 - val_loss: 0.1109
# Epoch 18/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9772 - loss: 0.1089 - val_accuracy: 0.9771 - val_loss: 0.1072
# Epoch 19/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9776 - loss: 0.1058 - val_accuracy: 0.9784 - val_loss: 0.1040
# Epoch 20/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9785 - loss: 0.1026 - val_accuracy: 0.9795 - val_loss: 0.1009
# Epoch 21/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9794 - loss: 0.0992 - val_accuracy: 0.9796 - val_loss: 0.0981
# Epoch 22/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9797 - loss: 0.0970 - val_accuracy: 0.9795 - val_loss: 0.0958
# Epoch 23/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9801 - loss: 0.0948 - val_accuracy: 0.9804 - val_loss: 0.0933
# Epoch 24/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9807 - loss: 0.0919 - val_accuracy: 0.9811 - val_loss: 0.0910
# Epoch 25/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9815 - loss: 0.0895 - val_accuracy: 0.9817 - val_loss: 0.0890
# Epoch 26/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9817 - loss: 0.0878 - val_accuracy: 0.9820 - val_loss: 0.0870
# Epoch 27/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9822 - loss: 0.0858 - val_accuracy: 0.9827 - val_loss: 0.0853
# Epoch 28/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9826 - loss: 0.0842 - val_accuracy: 0.9825 - val_loss: 0.0833
# Epoch 29/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9828 - loss: 0.0824 - val_accuracy: 0.9832 - val_loss: 0.0815
# Epoch 30/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9835 - loss: 0.0810 - val_accuracy: 0.9830 - val_loss: 0.0803
# Epoch 31/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9836 - loss: 0.0791 - val_accuracy: 0.9841 - val_loss: 0.0784
# Epoch 32/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9842 - loss: 0.0777 - val_accuracy: 0.9840 - val_loss: 0.0769
# Epoch 33/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9843 - loss: 0.0759 - val_accuracy: 0.9842 - val_loss: 0.0753
# Epoch 34/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9844 - loss: 0.0743 - val_accuracy: 0.9850 - val_loss: 0.0745
# Epoch 35/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9850 - loss: 0.0732 - val_accuracy: 0.9849 - val_loss: 0.0725
# Epoch 36/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9853 - loss: 0.0717 - val_accuracy: 0.9853 - val_loss: 0.0711
# Epoch 37/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9853 - loss: 0.0703 - val_accuracy: 0.9856 - val_loss: 0.0696
# Epoch 38/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9856 - loss: 0.0690 - val_accuracy: 0.9862 - val_loss: 0.0687
# Epoch 39/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9859 - loss: 0.0681 - val_accuracy: 0.9862 - val_loss: 0.0670
# Epoch 40/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9861 - loss: 0.0666 - val_accuracy: 0.9857 - val_loss: 0.0663
# Epoch 41/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9863 - loss: 0.0653 - val_accuracy: 0.9866 - val_loss: 0.0645
# Epoch 42/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9867 - loss: 0.0637 - val_accuracy: 0.9871 - val_loss: 0.0635
# Epoch 43/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9867 - loss: 0.0629 - val_accuracy: 0.9867 - val_loss: 0.0623
# Epoch 44/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9870 - loss: 0.0615 - val_accuracy: 0.9874 - val_loss: 0.0611
# Epoch 45/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9872 - loss: 0.0605 - val_accuracy: 0.9879 - val_loss: 0.0602
# Epoch 46/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9874 - loss: 0.0602 - val_accuracy: 0.9877 - val_loss: 0.0591
# Epoch 47/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9876 - loss: 0.0583 - val_accuracy: 0.9882 - val_loss: 0.0585
# Epoch 48/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9877 - loss: 0.0575 - val_accuracy: 0.9880 - val_loss: 0.0568
# Epoch 49/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9881 - loss: 0.0564 - val_accuracy: 0.9883 - val_loss: 0.0560
# Epoch 50/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9883 - loss: 0.0554 - val_accuracy: 0.9883 - val_loss: 0.0550
# Epoch 51/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9884 - loss: 0.0544 - val_accuracy: 0.9884 - val_loss: 0.0543
# Epoch 52/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9886 - loss: 0.0536 - val_accuracy: 0.9889 - val_loss: 0.0531
# Epoch 53/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9888 - loss: 0.0525 - val_accuracy: 0.9889 - val_loss: 0.0521
# Epoch 54/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9889 - loss: 0.0519 - val_accuracy: 0.9896 - val_loss: 0.0512
# Epoch 55/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9893 - loss: 0.0506 - val_accuracy: 0.9893 - val_loss: 0.0505
# Epoch 56/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9893 - loss: 0.0501 - val_accuracy: 0.9894 - val_loss: 0.0495
# Epoch 57/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9894 - loss: 0.0491 - val_accuracy: 0.9894 - val_loss: 0.0489
# Epoch 58/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9895 - loss: 0.0489 - val_accuracy: 0.9897 - val_loss: 0.0479
# Epoch 59/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9899 - loss: 0.0475 - val_accuracy: 0.9899 - val_loss: 0.0470
# Epoch 60/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9899 - loss: 0.0464 - val_accuracy: 0.9902 - val_loss: 0.0464
# Epoch 61/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9901 - loss: 0.0460 - val_accuracy: 0.9901 - val_loss: 0.0458
# Epoch 62/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9903 - loss: 0.0452 - val_accuracy: 0.9904 - val_loss: 0.0447
# Epoch 63/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9903 - loss: 0.0444 - val_accuracy: 0.9907 - val_loss: 0.0440
# Epoch 64/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9904 - loss: 0.0440 - val_accuracy: 0.9906 - val_loss: 0.0434
# Epoch 65/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9907 - loss: 0.0426 - val_accuracy: 0.9913 - val_loss: 0.0426
# Epoch 66/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9908 - loss: 0.0424 - val_accuracy: 0.9913 - val_loss: 0.0421
# Epoch 67/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9907 - loss: 0.0420 - val_accuracy: 0.9912 - val_loss: 0.0412
# Epoch 68/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9911 - loss: 0.0409 - val_accuracy: 0.9912 - val_loss: 0.0405
# Epoch 69/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9914 - loss: 0.0399 - val_accuracy: 0.9913 - val_loss: 0.0401
# Epoch 70/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9915 - loss: 0.0392 - val_accuracy: 0.9917 - val_loss: 0.0393
# Epoch 71/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9914 - loss: 0.0392 - val_accuracy: 0.9914 - val_loss: 0.0391
# Epoch 72/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9917 - loss: 0.0381 - val_accuracy: 0.9922 - val_loss: 0.0383
# Epoch 73/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9917 - loss: 0.0379 - val_accuracy: 0.9920 - val_loss: 0.0375
# Epoch 74/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9919 - loss: 0.0372 - val_accuracy: 0.9917 - val_loss: 0.0371
# Epoch 75/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9919 - loss: 0.0368 - val_accuracy: 0.9921 - val_loss: 0.0364
# Epoch 76/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9921 - loss: 0.0361 - val_accuracy: 0.9924 - val_loss: 0.0358
# Epoch 77/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9921 - loss: 0.0356 - val_accuracy: 0.9925 - val_loss: 0.0355
# Epoch 78/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9923 - loss: 0.0351 - val_accuracy: 0.9924 - val_loss: 0.0347
# Epoch 79/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9924 - loss: 0.0346 - val_accuracy: 0.9925 - val_loss: 0.0344
# Epoch 80/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9925 - loss: 0.0337 - val_accuracy: 0.9929 - val_loss: 0.0338
# Epoch 81/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9927 - loss: 0.0334 - val_accuracy: 0.9927 - val_loss: 0.0332
# Epoch 82/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9928 - loss: 0.0328 - val_accuracy: 0.9929 - val_loss: 0.0327
# Epoch 83/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9928 - loss: 0.0322 - val_accuracy: 0.9928 - val_loss: 0.0327
# Epoch 84/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9927 - loss: 0.0324 - val_accuracy: 0.9929 - val_loss: 0.0320
# Epoch 85/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9931 - loss: 0.0314 - val_accuracy: 0.9932 - val_loss: 0.0313
# Epoch 86/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9930 - loss: 0.0311 - val_accuracy: 0.9932 - val_loss: 0.0308
# Epoch 87/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9934 - loss: 0.0303 - val_accuracy: 0.9932 - val_loss: 0.0304
# Epoch 88/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9932 - loss: 0.0300 - val_accuracy: 0.9932 - val_loss: 0.0300
# Epoch 89/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9933 - loss: 0.0296 - val_accuracy: 0.9935 - val_loss: 0.0295
# Epoch 90/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9936 - loss: 0.0290 - val_accuracy: 0.9936 - val_loss: 0.0292
# Epoch 91/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9935 - loss: 0.0292 - val_accuracy: 0.9933 - val_loss: 0.0287
# Epoch 92/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9936 - loss: 0.0282 - val_accuracy: 0.9935 - val_loss: 0.0283
# Epoch 93/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9936 - loss: 0.0280 - val_accuracy: 0.9940 - val_loss: 0.0280
# Epoch 94/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9937 - loss: 0.0277 - val_accuracy: 0.9939 - val_loss: 0.0275
# Epoch 95/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9940 - loss: 0.0269 - val_accuracy: 0.9941 - val_loss: 0.0271
# Epoch 96/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9940 - loss: 0.0267 - val_accuracy: 0.9941 - val_loss: 0.0267
# Epoch 97/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9942 - loss: 0.0263 - val_accuracy: 0.9938 - val_loss: 0.0264
# Epoch 98/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9939 - loss: 0.0263 - val_accuracy: 0.9942 - val_loss: 0.0261
# Epoch 99/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9943 - loss: 0.0258 - val_accuracy: 0.9944 - val_loss: 0.0257
# Epoch 100/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9943 - loss: 0.0256 - val_accuracy: 0.9942 - val_loss: 0.0254

# %%
# Accessing the training loss history
training_loss = history.history['loss']

# Accessing the validation loss history
validation_loss = history.history['val_loss']

# %%
# Plot training & validation loss values
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
y_pred_prob = model.predict(x_test)
# Out:
# 5192/5192 ━━━━━━━━━━━━━━━━━━━━ 3s 584us/step

# %%
#plotando histograma da previsao e do valor real

plt.hist(y_test, bins=100, fill=False, histtype='step', label="real data")
plt.hist(y_pred_prob,bins=100, fill=False, histtype='step', label="predicted data")
plt.legend()

plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# Compute ROC curve and ROC area
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

#best threshold
J = tpr - fpr
best_threshold_index = np.argmax(J)
best_threshold = thresholds[best_threshold_index]

# Annotate some thresholds on the ROC curve
for i in range(0, len(thresholds), len(thresholds) // 10):
    plt.annotate(f'{thresholds[i]:.2f}', (fpr[i], tpr[i]), textcoords="offset points", xytext=(0,10), ha='center')

# Highlight the best threshold point
plt.scatter(fpr[best_threshold_index], tpr[best_threshold_index], color='red', label=f'Best Threshold = {best_threshold:.2f}')
plt.annotate(f'Threshold = {best_threshold:.2f}', 
             (fpr[best_threshold_index], tpr[best_threshold_index]), 
             textcoords="offset points", 
             xytext=(0,10), 
             ha='center', 
             color='red')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %%
#creating data with true rate: 1:10000

#arranjando os dados de forma aleatoria

data_with_rate=Data()

total=n_max_1*2
rate1=total*0.001
rate2=total-rate1

random1=np.random.choice(n_max_1,rate1,replace=False) #inteiros ate o primeiro numero. Numero de eventos sorteados igual ao segundo numero
random2=np.random.choice(n_max_2,rate2,replace=False)
random_position=np.random.choice(2*n_max_1,n_max_1,replace=False)

is_here=np.zeros(n_max_1*2)
is_here[random_position] = 1


cont1=0
cont2=0

for cont in range(n_max_1*2):
    if is_here[cont]==0:

        data_with_rate.ak15_regressed_mass.append(data_1.ak15_regressed_mass[random1[cont1]])
        data_with_rate.lep1_pt.append(data_1.lep1_pt[random1[cont1]])
        data_with_rate.lep1_eta.append(data_1.lep1_eta[random1[cont1]])
        data_with_rate.lep1_phi.append(data_1.lep1_phi[random1[cont1]])
        data_with_rate.lep1_mass.append(data_1.lep1_mass[random1[cont1]])
        data_with_rate.lep2_pt.append(data_1.lep2_pt[random1[cont1]])
        data_with_rate.lep2_eta.append(data_1.lep2_eta[random1[cont1]])
        data_with_rate.lep2_phi.append(data_1.lep2_phi[random1[cont1]])
        data_with_rate.lep2_mass.append(data_1.lep2_mass[random1[cont1]])
        data_with_rate.ak15_pt.append(data_1.ak15_pt[random1[cont1]])
        data_with_rate.ak15_eta.append(data_1.ak15_eta[random1[cont1]])
        data_with_rate.ak15_phi.append(data_1.ak15_phi[random1[cont1]])
        data_with_rate.ak15_deltaR_sj12.append(data_1.ak15_deltaR_sj12[random1[cont1]])
        data_with_rate.ak15_sj1_pt.append(data_1.ak15_sj1_pt[random1[cont1]])
        data_with_rate.ak15_sj2_pt.append(data_1.ak15_sj2_pt[random1[cont1]])

        data_with_rate.truth.append(1)
        cont1=cont1+1

    if is_here[cont]==0:
        data_with_rate.ak15_regressed_mass.append(data_2.ak15_regressed_mass[random2[cont2]])
        data_with_rate.lep1_pt.append(data_2.lep1_pt[random2[cont2]])
        data_with_rate.lep1_eta.append(data_2.lep1_eta[random2[cont2]])
        data_with_rate.lep1_phi.append(data_2.lep1_phi[random2[cont2]])
        data_with_rate.lep1_mass.append(data_2.lep1_mass[random2[cont2]])
        data_with_rate.lep2_pt.append(data_2.lep2_pt[random2[cont2]])
        data_with_rate.lep2_eta.append(data_2.lep2_eta[random2[cont2]])
        data_with_rate.lep2_phi.append(data_2.lep2_phi[random2[cont2]])
        data_with_rate.lep2_mass.append(data_2.lep2_mass[random2[cont2]])
        data_with_rate.ak15_pt.append(data_2.ak15_pt[random2[cont2]])
        data_with_rate.ak15_eta.append(data_2.ak15_eta[random2[cont2]])
        data_with_rate.ak15_phi.append(data_2.ak15_phi[random2[cont2]])
        data_with_rate.ak15_deltaR_sj12.append(data_2.ak15_deltaR_sj12[random2[cont2]])
        data_with_rate.ak15_sj1_pt.append(data_2.ak15_sj1_pt[random2[cont2]])
        data_with_rate.ak15_sj2_pt.append(data_2.ak15_sj2_pt[random2[cont2]])

        data_with_rate.truth.append(0)
        cont2=cont2+1
