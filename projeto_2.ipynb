# %%
import ROOT
import matplotlib.pyplot as plt
import numpy as np
import keras

# %%
#vamos abrir os arquivos root
nome1="vhcc_tree.root"
nome2="dyll-nlo_tree.root"
file1= ROOT.TFile.Open( nome1 , "READ" )
file2= ROOT.TFile.Open( nome2 , "READ" )

# %%
#vamos pegar a TTree
tree1 = file1.Get("Events")
tree2 = file2.Get("Events")

# %%
#coletando os dados
from data_classes import Data

data_1=Data()
data_2=Data()

n_max_1=tree1.GetEntries()

for entryNum in range (0 ,n_max_1):
    tree1.GetEntry( entryNum )
    data_1.ak15_regressed_mass.append(getattr(tree1, "ak15_regressed_mass"))
    data_1.lep1_pt.append(getattr(tree1, "lep1_pt"))
    data_1.lep1_eta.append(getattr(tree1, "lep1_eta"))
    data_1.lep1_phi.append(getattr(tree1, "lep1_phi"))
    data_1.lep1_mass.append(getattr(tree1, "lep1_mass"))
    data_1.lep2_pt.append(getattr(tree1, "lep2_pt"))
    data_1.lep2_eta.append(getattr(tree1, "lep2_eta"))
    data_1.lep2_phi.append(getattr(tree1, "lep2_phi"))
    data_1.lep2_mass.append(getattr(tree1, "lep2_mass"))
    data_1.ak15_pt.append(getattr(tree1, "ak15_pt"))
    data_1.ak15_eta.append(getattr(tree1, "ak15_eta"))
    data_1.ak15_phi.append(getattr(tree1, "ak15_phi"))
    data_1.ak15_deltaR_sj12.append(getattr(tree1, "ak15_deltaR_sj12"))
    data_1.ak15_sj1_pt.append(getattr(tree1, "ak15_sj1_pt"))
    data_1.ak15_sj2_pt.append(getattr(tree1, "ak15_sj2_pt"))      

n_max_2=tree2.GetEntries()

for entryNum in range (0 ,n_max_2):
    tree2.GetEntry( entryNum )
    data_2.ak15_regressed_mass.append(getattr(tree2, "ak15_regressed_mass"))
    data_2.lep1_pt.append(getattr(tree1, "lep1_pt"))
    data_2.lep1_eta.append(getattr(tree1, "lep1_eta"))
    data_2.lep1_phi.append(getattr(tree1, "lep1_phi"))
    data_2.lep1_mass.append(getattr(tree1, "lep1_mass"))
    data_2.lep2_pt.append(getattr(tree1, "lep2_pt"))
    data_2.lep2_eta.append(getattr(tree1, "lep2_eta"))
    data_2.lep2_phi.append(getattr(tree1, "lep2_phi"))
    data_2.lep2_mass.append(getattr(tree1, "lep2_mass"))
    data_2.ak15_pt.append(getattr(tree1, "ak15_pt"))
    data_2.ak15_eta.append(getattr(tree1, "ak15_eta"))
    data_2.ak15_phi.append(getattr(tree1, "ak15_phi"))
    data_2.ak15_deltaR_sj12.append(getattr(tree1, "ak15_deltaR_sj12"))
    data_2.ak15_sj1_pt.append(getattr(tree1, "ak15_sj1_pt"))
    data_2.ak15_sj2_pt.append(getattr(tree1, "ak15_sj2_pt"))

# %%
#plotando histograma de massa?

plt.hist( data_1.ak15_regressed_mass,bins=100,fill=False, histtype='step', label="higgs data")
plt.hist( data_2.ak15_regressed_mass[:n_max_1],bins=100, fill=False, histtype='step', label="background data")
plt.legend()

plt.draw()

# %%
#arranjando os dados de forma aleatoria

data=Data()

random1=np.random.choice(n_max_1,n_max_1,replace=False) #inteiros ate o primeiro numero. Numero de eventos sorteados igual ao segundo numero
random2=np.random.choice(n_max_2,n_max_1,replace=False)
random_position=np.random.choice(2*n_max_1,n_max_1,replace=False)

is_here=np.zeros(n_max_1*2)
is_here[random_position] = 1


cont1=0
cont2=0

for cont in range(n_max_1*2):
    if is_here[cont]==1:

        data.ak15_regressed_mass.append(data_1.ak15_regressed_mass[random1[cont1]])
        data.lep1_pt.append(data_1.lep1_pt[random1[cont1]])
        data.lep1_eta.append(data_1.lep1_eta[random1[cont1]])
        data.lep1_phi.append(data_1.lep1_phi[random1[cont1]])
        data.lep1_mass.append(data_1.lep1_mass[random1[cont1]])
        data.lep2_pt.append(data_1.lep2_pt[random1[cont1]])
        data.lep2_eta.append(data_1.lep2_eta[random1[cont1]])
        data.lep2_phi.append(data_1.lep2_phi[random1[cont1]])
        data.lep2_mass.append(data_1.lep2_mass[random1[cont1]])
        data.ak15_pt.append(data_1.ak15_pt[random1[cont1]])
        data.ak15_eta.append(data_1.ak15_eta[random1[cont1]])
        data.ak15_phi.append(data_1.ak15_phi[random1[cont1]])
        data.ak15_deltaR_sj12.append(data_1.ak15_deltaR_sj12[random1[cont1]])
        data.ak15_sj1_pt.append(data_1.ak15_sj1_pt[random1[cont1]])
        data.ak15_sj2_pt.append(data_1.ak15_sj2_pt[random1[cont1]])

        data.truth.append(1)
        cont1=cont1+1

    if is_here[cont]==0:
        data.ak15_regressed_mass.append(data_2.ak15_regressed_mass[random2[cont2]])
        data.lep1_pt.append(data_2.lep1_pt[random2[cont2]])
        data.lep1_eta.append(data_2.lep1_eta[random2[cont2]])
        data.lep1_phi.append(data_2.lep1_phi[random2[cont2]])
        data.lep1_mass.append(data_2.lep1_mass[random2[cont2]])
        data.lep2_pt.append(data_2.lep2_pt[random2[cont2]])
        data.lep2_eta.append(data_2.lep2_eta[random2[cont2]])
        data.lep2_phi.append(data_2.lep2_phi[random2[cont2]])
        data.lep2_mass.append(data_2.lep2_mass[random2[cont2]])
        data.ak15_pt.append(data_2.ak15_pt[random2[cont2]])
        data.ak15_eta.append(data_2.ak15_eta[random2[cont2]])
        data.ak15_phi.append(data_2.ak15_phi[random2[cont2]])
        data.ak15_deltaR_sj12.append(data_2.ak15_deltaR_sj12[random2[cont2]])
        data.ak15_sj1_pt.append(data_2.ak15_sj1_pt[random2[cont2]])
        data.ak15_sj2_pt.append(data_2.ak15_sj2_pt[random2[cont2]])

        data.truth.append(0)
        cont2=cont2+1

# %%
#modelo da rede neural sendo montado
#vamos tentar no comeco apesar usar os dados de ak?

from keras import models,layers,initializers

model= models.Sequential(name="my_neural")
model.add(layers.Input(shape=(6,)))
model.add(layers.Dense(8,activation="relu"))
model.add(layers.Dense(8,activation="relu"))
model.add(layers.Dense(1,activation="sigmoid"))

model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
def make_correction_format(data_in):
    return np.array(data_in).reshape(1,-1)

# %%
#tenho que montar eu mesmo
n_max=len(data.truth)
input_data = [[] for _ in range(6)]

input_data[0]=np.array(data.ak15_pt)
input_data[1]=np.array(data.ak15_eta)
input_data[2]=np.array(data.ak15_phi)
input_data[3]=np.array(data.ak15_deltaR_sj12)
input_data[4]=np.array(data.ak15_sj1_pt)
input_data[5]=np.array(data.ak15_sj2_pt)

input_data=np.array(input_data).transpose()

input_data=np.stack(input_data,axis=0)

# %%
#separando os dados
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(input_data,data.truth,random_state=42)

# %%
x_train=np.array(x_train)
y_train=np.array(y_train)
x_test=np.array(x_test)
y_test=np.array(y_test)

# %%
model.summary()
# Out:
# Model: "my_neural"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 8)              │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 137 (548.00 B)
#  Trainable params: 137 (548.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#treino
history = model.fit(x_train,y_train,epochs=100,batch_size=15000,validation_data=(x_test,y_test))
# Out:
# Epoch 1/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5005 - loss: 38.9515 - val_accuracy: 0.4994 - val_loss: 6.2242
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4634 - loss: 3.4939 - val_accuracy: 0.0682 - val_loss: 1.6954
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2430 - loss: 1.5507 - val_accuracy: 0.2777 - val_loss: 1.2869
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2495 - loss: 1.2297 - val_accuracy: 0.2997 - val_loss: 1.0483
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3000 - loss: 0.9944 - val_accuracy: 0.3424 - val_loss: 0.8478
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3604 - loss: 0.8075 - val_accuracy: 0.4221 - val_loss: 0.7046
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5035 - loss: 0.6808 - val_accuracy: 0.9274 - val_loss: 0.6148
# Epoch 8/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9314 - loss: 0.6009 - val_accuracy: 0.9343 - val_loss: 0.5572
# Epoch 9/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9308 - loss: 0.5458 - val_accuracy: 0.9279 - val_loss: 0.5146
# Epoch 10/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9277 - loss: 0.5069 - val_accuracy: 0.9263 - val_loss: 0.4794
# Epoch 11/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9271 - loss: 0.4734 - val_accuracy: 0.9254 - val_loss: 0.4488
# Epoch 12/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9275 - loss: 0.4433 - val_accuracy: 0.9305 - val_loss: 0.4211
# Epoch 13/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9284 - loss: 0.4149 - val_accuracy: 0.9299 - val_loss: 0.3952
# Epoch 14/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9293 - loss: 0.3892 - val_accuracy: 0.9306 - val_loss: 0.3704
# Epoch 15/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9310 - loss: 0.3657 - val_accuracy: 0.9313 - val_loss: 0.3464
# Epoch 16/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9335 - loss: 0.3406 - val_accuracy: 0.9380 - val_loss: 0.3226
# Epoch 17/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9377 - loss: 0.3163 - val_accuracy: 0.9416 - val_loss: 0.2971
# Epoch 18/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9439 - loss: 0.2904 - val_accuracy: 0.9567 - val_loss: 0.2643
# Epoch 19/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9601 - loss: 0.2600 - val_accuracy: 0.9610 - val_loss: 0.2491
# Epoch 20/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9605 - loss: 0.2469 - val_accuracy: 0.9650 - val_loss: 0.2378
# Epoch 21/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9617 - loss: 0.2348 - val_accuracy: 0.9625 - val_loss: 0.2257
# Epoch 22/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9623 - loss: 0.2237 - val_accuracy: 0.9653 - val_loss: 0.2153
# Epoch 23/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9641 - loss: 0.2139 - val_accuracy: 0.9634 - val_loss: 0.2057
# Epoch 24/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9643 - loss: 0.2045 - val_accuracy: 0.9650 - val_loss: 0.1969
# Epoch 25/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9653 - loss: 0.1963 - val_accuracy: 0.9656 - val_loss: 0.1886
# Epoch 26/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9665 - loss: 0.1880 - val_accuracy: 0.9662 - val_loss: 0.1810
# Epoch 27/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9668 - loss: 0.1794 - val_accuracy: 0.9680 - val_loss: 0.1733
# Epoch 28/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9686 - loss: 0.1723 - val_accuracy: 0.9665 - val_loss: 0.1666
# Epoch 29/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9685 - loss: 0.1662 - val_accuracy: 0.9692 - val_loss: 0.1601
# Epoch 30/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9693 - loss: 0.1587 - val_accuracy: 0.9720 - val_loss: 0.1538
# Epoch 31/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9713 - loss: 0.1529 - val_accuracy: 0.9729 - val_loss: 0.1473
# Epoch 32/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9719 - loss: 0.1464 - val_accuracy: 0.9744 - val_loss: 0.1422
# Epoch 33/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9731 - loss: 0.1408 - val_accuracy: 0.9747 - val_loss: 0.1366
# Epoch 34/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9742 - loss: 0.1358 - val_accuracy: 0.9750 - val_loss: 0.1316
# Epoch 35/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9750 - loss: 0.1311 - val_accuracy: 0.9759 - val_loss: 0.1267
# Epoch 36/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9755 - loss: 0.1266 - val_accuracy: 0.9749 - val_loss: 0.1222
# Epoch 37/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9761 - loss: 0.1210 - val_accuracy: 0.9771 - val_loss: 0.1179
# Epoch 38/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9771 - loss: 0.1171 - val_accuracy: 0.9780 - val_loss: 0.1139
# Epoch 39/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9777 - loss: 0.1129 - val_accuracy: 0.9769 - val_loss: 0.1102
# Epoch 40/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9781 - loss: 0.1092 - val_accuracy: 0.9795 - val_loss: 0.1066
# Epoch 41/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9789 - loss: 0.1057 - val_accuracy: 0.9785 - val_loss: 0.1027
# Epoch 42/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9793 - loss: 0.1019 - val_accuracy: 0.9794 - val_loss: 0.0994
# Epoch 43/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9798 - loss: 0.0993 - val_accuracy: 0.9814 - val_loss: 0.0972
# Epoch 44/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9806 - loss: 0.0959 - val_accuracy: 0.9810 - val_loss: 0.0933
# Epoch 45/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9807 - loss: 0.0931 - val_accuracy: 0.9818 - val_loss: 0.0904
# Epoch 46/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9813 - loss: 0.0904 - val_accuracy: 0.9823 - val_loss: 0.0877
# Epoch 47/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9819 - loss: 0.0877 - val_accuracy: 0.9813 - val_loss: 0.0850
# Epoch 48/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9822 - loss: 0.0847 - val_accuracy: 0.9836 - val_loss: 0.0827
# Epoch 49/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9829 - loss: 0.0823 - val_accuracy: 0.9829 - val_loss: 0.0802
# Epoch 50/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9832 - loss: 0.0800 - val_accuracy: 0.9833 - val_loss: 0.0780
# Epoch 51/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0779 - val_accuracy: 0.9843 - val_loss: 0.0757
# Epoch 52/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9838 - loss: 0.0758 - val_accuracy: 0.9827 - val_loss: 0.0738
# Epoch 53/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9838 - loss: 0.0734 - val_accuracy: 0.9844 - val_loss: 0.0718
# Epoch 54/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9843 - loss: 0.0716 - val_accuracy: 0.9848 - val_loss: 0.0699
# Epoch 55/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9849 - loss: 0.0698 - val_accuracy: 0.9848 - val_loss: 0.0679
# Epoch 56/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9851 - loss: 0.0680 - val_accuracy: 0.9849 - val_loss: 0.0663
# Epoch 57/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9852 - loss: 0.0665 - val_accuracy: 0.9851 - val_loss: 0.0648
# Epoch 58/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9856 - loss: 0.0647 - val_accuracy: 0.9858 - val_loss: 0.0630
# Epoch 59/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9859 - loss: 0.0633 - val_accuracy: 0.9871 - val_loss: 0.0616
# Epoch 60/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9862 - loss: 0.0615 - val_accuracy: 0.9868 - val_loss: 0.0599
# Epoch 61/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9866 - loss: 0.0601 - val_accuracy: 0.9861 - val_loss: 0.0591
# Epoch 62/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9866 - loss: 0.0592 - val_accuracy: 0.9871 - val_loss: 0.0572
# Epoch 63/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9870 - loss: 0.0571 - val_accuracy: 0.9874 - val_loss: 0.0560
# Epoch 64/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9872 - loss: 0.0560 - val_accuracy: 0.9875 - val_loss: 0.0547
# Epoch 65/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9874 - loss: 0.0549 - val_accuracy: 0.9879 - val_loss: 0.0533
# Epoch 66/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9875 - loss: 0.0534 - val_accuracy: 0.9882 - val_loss: 0.0523
# Epoch 67/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9876 - loss: 0.0526 - val_accuracy: 0.9884 - val_loss: 0.0513
# Epoch 68/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9880 - loss: 0.0514 - val_accuracy: 0.9894 - val_loss: 0.0505
# Epoch 69/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9885 - loss: 0.0501 - val_accuracy: 0.9885 - val_loss: 0.0491
# Epoch 70/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9882 - loss: 0.0492 - val_accuracy: 0.9889 - val_loss: 0.0479
# Epoch 71/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9887 - loss: 0.0478 - val_accuracy: 0.9893 - val_loss: 0.0470
# Epoch 72/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9889 - loss: 0.0469 - val_accuracy: 0.9901 - val_loss: 0.0463
# Epoch 73/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9893 - loss: 0.0462 - val_accuracy: 0.9897 - val_loss: 0.0451
# Epoch 74/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9892 - loss: 0.0453 - val_accuracy: 0.9893 - val_loss: 0.0445
# Epoch 75/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9892 - loss: 0.0444 - val_accuracy: 0.9904 - val_loss: 0.0435
# Epoch 76/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9899 - loss: 0.0432 - val_accuracy: 0.9897 - val_loss: 0.0425
# Epoch 77/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9897 - loss: 0.0425 - val_accuracy: 0.9902 - val_loss: 0.0417
# Epoch 78/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9897 - loss: 0.0421 - val_accuracy: 0.9901 - val_loss: 0.0409
# Epoch 79/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0413 - val_accuracy: 0.9901 - val_loss: 0.0404
# Epoch 80/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9899 - loss: 0.0407 - val_accuracy: 0.9905 - val_loss: 0.0396
# Epoch 81/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9902 - loss: 0.0400 - val_accuracy: 0.9908 - val_loss: 0.0387
# Epoch 82/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9905 - loss: 0.0392 - val_accuracy: 0.9910 - val_loss: 0.0382
# Epoch 83/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9904 - loss: 0.0383 - val_accuracy: 0.9909 - val_loss: 0.0375
# Epoch 84/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9908 - loss: 0.0377 - val_accuracy: 0.9911 - val_loss: 0.0367
# Epoch 85/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9908 - loss: 0.0367 - val_accuracy: 0.9917 - val_loss: 0.0362
# Epoch 86/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9909 - loss: 0.0363 - val_accuracy: 0.9914 - val_loss: 0.0355
# Epoch 87/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9910 - loss: 0.0359 - val_accuracy: 0.9917 - val_loss: 0.0348
# Epoch 88/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9913 - loss: 0.0352 - val_accuracy: 0.9919 - val_loss: 0.0345
# Epoch 89/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9912 - loss: 0.0348 - val_accuracy: 0.9918 - val_loss: 0.0338
# Epoch 90/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9916 - loss: 0.0337 - val_accuracy: 0.9922 - val_loss: 0.0332
# Epoch 91/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9917 - loss: 0.0332 - val_accuracy: 0.9922 - val_loss: 0.0327
# Epoch 92/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9916 - loss: 0.0330 - val_accuracy: 0.9925 - val_loss: 0.0322
# Epoch 93/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0326 - val_accuracy: 0.9923 - val_loss: 0.0317
# Epoch 94/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9920 - loss: 0.0318 - val_accuracy: 0.9927 - val_loss: 0.0312
# Epoch 95/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9920 - loss: 0.0316 - val_accuracy: 0.9924 - val_loss: 0.0306
# Epoch 96/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9922 - loss: 0.0308 - val_accuracy: 0.9924 - val_loss: 0.0303
# Epoch 97/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9922 - loss: 0.0304 - val_accuracy: 0.9929 - val_loss: 0.0297
# Epoch 98/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9924 - loss: 0.0300 - val_accuracy: 0.9925 - val_loss: 0.0291
# Epoch 99/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9924 - loss: 0.0293 - val_accuracy: 0.9931 - val_loss: 0.0287
# Epoch 100/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9925 - loss: 0.0293 - val_accuracy: 0.9927 - val_loss: 0.0283

# %%
# Accessing the training loss history
training_loss = history.history['loss']

# Accessing the validation loss history
validation_loss = history.history['val_loss']

# %%
# Plot training & validation loss values
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#plotando histograma da previsao e do valor real
y_pred_prob = model.predict(x_test) 
plt.hist(y_test, bins=100, fill=False, histtype='step', label="real data")
plt.hist(y_pred_prob,bins=100, fill=False, histtype='step', label="predicted data")
plt.legend()

plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# Compute ROC curve and ROC area
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

#best threshold
J = tpr - fpr
best_threshold_index = np.argmax(J)
best_threshold = thresholds[best_threshold_index]

# Annotate some thresholds on the ROC curve
for i in range(0, len(thresholds), len(thresholds) // 10):
    plt.annotate(f'{thresholds[i]:.2f}', (fpr[i], tpr[i]), textcoords="offset points", xytext=(0,10), ha='center')

# Highlight the best threshold point
plt.scatter(fpr[best_threshold_index], tpr[best_threshold_index], color='red', label=f'Best Threshold = {best_threshold:.2f}')
plt.annotate(f'Threshold = {best_threshold:.2f}', 
             (fpr[best_threshold_index], tpr[best_threshold_index]), 
             textcoords="offset points", 
             xytext=(0,10), 
             ha='center', 
             color='red')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %%
#creating data with true rate: 1:10000

#arranjando os dados de forma aleatoria

data_with_rate=Data()

total=n_max_1*2
rate1=int(total*0.001)
rate2=total-rate1

random1=np.random.choice(n_max_1,rate1,replace=False) #inteiros ate o primeiro numero. Numero de eventos sorteados igual ao segundo numero
random2=np.random.choice(n_max_2,rate2,replace=False)

random_position=np.random.choice(2*n_max_1,rate1,replace=False)

is_here=np.zeros(n_max_1*2)
is_here[random_position] = 1

cont1=0
cont2=0

for cont in range(n_max_1*2):
    if is_here[cont]==1:
        data_with_rate.ak15_regressed_mass.append(data_1.ak15_regressed_mass[random1[cont1]])
        data_with_rate.lep1_pt.append(data_1.lep1_pt[random1[cont1]])
        data_with_rate.lep1_eta.append(data_1.lep1_eta[random1[cont1]])
        data_with_rate.lep1_phi.append(data_1.lep1_phi[random1[cont1]])
        data_with_rate.lep1_mass.append(data_1.lep1_mass[random1[cont1]])
        data_with_rate.lep2_pt.append(data_1.lep2_pt[random1[cont1]])
        data_with_rate.lep2_eta.append(data_1.lep2_eta[random1[cont1]])
        data_with_rate.lep2_phi.append(data_1.lep2_phi[random1[cont1]])
        data_with_rate.lep2_mass.append(data_1.lep2_mass[random1[cont1]])
        data_with_rate.ak15_pt.append(data_1.ak15_pt[random1[cont1]])
        data_with_rate.ak15_eta.append(data_1.ak15_eta[random1[cont1]])
        data_with_rate.ak15_phi.append(data_1.ak15_phi[random1[cont1]])
        data_with_rate.ak15_deltaR_sj12.append(data_1.ak15_deltaR_sj12[random1[cont1]])
        data_with_rate.ak15_sj1_pt.append(data_1.ak15_sj1_pt[random1[cont1]])
        data_with_rate.ak15_sj2_pt.append(data_1.ak15_sj2_pt[random1[cont1]])

        data_with_rate.truth.append(1)
        cont1=cont1+1



    if is_here[cont]==0:
        data_with_rate.ak15_regressed_mass.append(data_2.ak15_regressed_mass[random2[cont2]])
        data_with_rate.lep1_pt.append(data_2.lep1_pt[random2[cont2]])
        data_with_rate.lep1_eta.append(data_2.lep1_eta[random2[cont2]])
        data_with_rate.lep1_phi.append(data_2.lep1_phi[random2[cont2]])
        data_with_rate.lep1_mass.append(data_2.lep1_mass[random2[cont2]])
        data_with_rate.lep2_pt.append(data_2.lep2_pt[random2[cont2]])
        data_with_rate.lep2_eta.append(data_2.lep2_eta[random2[cont2]])
        data_with_rate.lep2_phi.append(data_2.lep2_phi[random2[cont2]])
        data_with_rate.lep2_mass.append(data_2.lep2_mass[random2[cont2]])
        data_with_rate.ak15_pt.append(data_2.ak15_pt[random2[cont2]])
        data_with_rate.ak15_eta.append(data_2.ak15_eta[random2[cont2]])
        data_with_rate.ak15_phi.append(data_2.ak15_phi[random2[cont2]])
        data_with_rate.ak15_deltaR_sj12.append(data_2.ak15_deltaR_sj12[random2[cont2]])
        data_with_rate.ak15_sj1_pt.append(data_2.ak15_sj1_pt[random2[cont2]])
        data_with_rate.ak15_sj2_pt.append(data_2.ak15_sj2_pt[random2[cont2]])

        data_with_rate.truth.append(0)
        cont2=cont2+1

# %%
#tenho que montar eu mesmo
n_max=len(data_with_rate.truth)
input_data = [[] for _ in range(6)]

input_data[0]=np.array(data_with_rate.ak15_pt)
input_data[1]=np.array(data_with_rate.ak15_eta)
input_data[2]=np.array(data_with_rate.ak15_phi)
input_data[3]=np.array(data_with_rate.ak15_deltaR_sj12)
input_data[4]=np.array(data_with_rate.ak15_sj1_pt)
input_data[5]=np.array(data_with_rate.ak15_sj2_pt)

input_data=np.array(input_data).transpose()

input_data=np.stack(input_data,axis=0)

# %%
#plotando histograma da previsao e do valor real
y_pred_prob = model.predict(input_data) 
plt.hist(data_with_rate.truth, bins=100, fill=False, histtype='step', label="real data")
plt.hist(y_pred_prob,bins=100, fill=False, histtype='step', label="predicted data")
plt.legend()

plt.show()
# Out:
# 20766/20766 ━━━━━━━━━━━━━━━━━━━━ 9s 419us/step

# %%
# Compute ROC curve and ROC area
fpr, tpr, thresholds = roc_curve(data_with_rate.truth, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

#best threshold
J = tpr - fpr
best_threshold_index = np.argmax(J)
best_threshold = thresholds[best_threshold_index]

# Annotate some thresholds on the ROC curve
for i in range(0, len(thresholds), len(thresholds) // 10):
    plt.annotate(f'{thresholds[i]:.2f}', (fpr[i], tpr[i]), textcoords="offset points", xytext=(0,10), ha='center')

# Highlight the best threshold point
plt.scatter(fpr[best_threshold_index], tpr[best_threshold_index], color='red', label=f'Best Threshold = {best_threshold:.2f}')
plt.annotate(f'Threshold = {best_threshold:.2f}', 
             (fpr[best_threshold_index], tpr[best_threshold_index]), 
             textcoords="offset points", 
             xytext=(0,10), 
             ha='center', 
             color='red')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %%
tpr[best_threshold_index]
# Out:
# 1.0
